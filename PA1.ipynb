# %% [markdown]
# # Griffin Colasanti - Markdown Practice

# %% [markdown]
# ### My name is Griffin Colasanti, and I am an actuarial science student at Bellarmine University. I am interested in learning how coding can be used to solve problems, analyze data, and make tasks more efficient. I am looking forward to developing my programming skills in this course.

# %% [markdown]
# - Programming Assignments
# - Quizzes
# - Attendance/In-class Participation
# - Exams
# - Projects

# %% [markdown]
# 1. Module 1: Course Introduction
# 2. Module 1: Variables, Simple Data Types, and GitHub
# 3. Module 2: Lists and Tuples Part 1
# 4. Module 3: If Statements
# 5. Module 4: Loops
# 6. Module 5: Lists and Tuples Part 2
# 7. Module 6: Dictionaries
# 8. Module 7: Sets, Functions, Libraries
# 9. Module 8: Class Datatypes and Exceptions
# 10. Module 9: NumPy Arrays
# 11. Module 10: Pandas and Files

# %% [markdown]
# The primary programming language I will learn in this course is **Python**.

# %% [markdown]
# I am using *Jupyter Notebook* to create and edit my .ipynb file.

# %% [markdown]
# Today I `completed my CS 150 assignment and learned more about Python`.

# %% [markdown]
# My GitHub repository: [CS 150 - Griffin Colasanti](https://github.com/GriffinColasanti/CS150-Griffin-Colasanti)

# %% [markdown]
# ![Bellarmine University Logo](https://i.pinimg.com/736x/62/c5/c5/62c5c5ac420b7e823cd7a908f5d5d0d1.jpg)

# %% [markdown]
# In this Markdown practice, I learned how to use different Markdown formatting techniques in Jupyter Notebook. I learned how to create headings, bullet lists, ordered lists, bold and italic text, highlighted text, hyperlinks, and display images. I also learned how Markdown can be used to organize and present information in a clear way.
